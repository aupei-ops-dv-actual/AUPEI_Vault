# %%
# !pip install qiskit

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bdd949994946> in <cell line: 0>()
# ----> 1 from qiskit import IBMQ
#       2
#       3 # Save your IBM Quantum token
#       4 IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
#
# ModuleNotFoundError: No module named 'qiskit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install qiskit

# %%
# !pip install qiskit-aer

# %%
# !pip install qiskit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 73.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 830.0 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 67.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 9.4 MB/s eta 0:00:00
# ...

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)

# %%
# !pip install qiskit

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-bdd949994946> in <cell line: 0>()
# ----> 1 from qiskit import IBMQ
#       2
#       3 # Save your IBM Quantum token
#       4 IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
#
# ImportError: cannot import name 'IBMQ' from 'qiskit' (/usr/local/lib/python3.11/dist-packages/qiskit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install qiskit-ibmq-provider
from qiskit_ibmq_provider import IBMQ
# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.5/241.5 kB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 72.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 40.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# blosc2 3.0.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# chex 0.1.88 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
provider = IBMQ.get_provider(hub='ibm-q')
print("Available Backends:")
print([backend.name() for backend in provider.backends()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-884a04e64743> in <cell line: 0>()
# ----> 1 provider = IBMQ.get_provider(hub='ibm-q')
#       2 print("Available Backends:")
#       3 print([backend.name() for backend in provider.backends()])
#
# NameError: name 'IBMQ' is not defined

# %%
# !pip install qiskit-ibmq-provider
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)

# Load your IBM Quantum account
provider = IBMQ.load_account() # This loads the account you saved above.

# Get the provider for the 'ibm-q' hub
provider = IBMQ.get_provider(hub='ibm-q')

print("Available Backends:")
print([backend.name() for backend in provider.backends()])
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-37918bdfa55a> in <cell line: 0>()
#       1 get_ipython().system('pip install qiskit-ibmq-provider')
# ----> 2 from qiskit import IBMQ
#       3
#       4 # Save your IBM Quantum token
#       5 IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
#
# /usr/local/lib/python3.11/dist-packages/qiskit/__init__.py in <module>
#      36     _suppress_error = os.environ.get("QISKIT_SUPPRESS_1_0_IMPORT_ERROR", False) == "1"
#      37     if int(_major) > 0 and not _suppress_error:
# ---> 38         raise ImportError(
#      39             "Qiskit is installed in an invalid environment that has both Qiskit >=1.0"
#      40             " and an earlier version."
#
# ...

# %%
# !pip uninstall -y qiskit qiskit-terra qiskit-aer qiskit-ibmq-provider qiskit-ignis
# Out:
# Found existing installation: qiskit 1.3.1
# Uninstalling qiskit-1.3.1:
#   Successfully uninstalled qiskit-1.3.1
# Found existing installation: qiskit-terra 0.46.3
# Uninstalling qiskit-terra-0.46.3:
#   Successfully uninstalled qiskit-terra-0.46.3
# WARNING: Skipping qiskit-aer as it is not installed.
# Found existing installation: qiskit-ibmq-provider 0.20.2
# Uninstalling qiskit-ibmq-provider-0.20.2:
#   Successfully uninstalled qiskit-ibmq-provider-0.20.2
# WARNING: Skipping qiskit-ignis as it is not installed.

# %%
# !pip install qiskit qiskit-aer qiskit-ibmq-provider
# Out:
# ...
#   Using cached qiskit-1.3.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# ...
#   Using cached qiskit_ibmq_provider-0.20.2-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached qiskit_terra-0.46.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# ...
# Using cached qiskit-1.3.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 94.6 MB/s eta 0:00:00
# Using cached qiskit_ibmq_provider-0.20.2-py3-none-any.whl (241 kB)
# Using cached qiskit_terra-0.46.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# ...

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-bdd949994946> in <cell line: 0>()
# ----> 1 from qiskit import IBMQ
#       2
#       3 # Save your IBM Quantum token
#       4 IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
#
# /usr/local/lib/python3.11/dist-packages/qiskit/__init__.py in <module>
#      34     _suppress_error = os.environ.get("QISKIT_SUPPRESS_1_0_IMPORT_ERROR", False) == "1"
#      35     if not _suppress_error and _has_tools:
# ---> 36         raise ImportError(
#      37             "Qiskit is installed in an invalid environment that has both Qiskit >=1.0"
#      38             " and an earlier version."
#
# ...

# %%
# !pip uninstall -y qiskit qiskit-terra qiskit-aer qiskit-ibmq-provider qiskit-ignis # Remove all qiskit related packages
# !pip install qiskit qiskit-aer qiskit-ibmq-provider # Reinstall qiskit, aer and ibmq provider
# Out:
# Found existing installation: qiskit 1.3.1
# Uninstalling qiskit-1.3.1:
#   Successfully uninstalled qiskit-1.3.1
# Found existing installation: qiskit-terra 0.46.3
# Uninstalling qiskit-terra-0.46.3:
#   Successfully uninstalled qiskit-terra-0.46.3
# Found existing installation: qiskit-aer 0.16.0
# Uninstalling qiskit-aer-0.16.0:
#   Successfully uninstalled qiskit-aer-0.16.0
# Found existing installation: qiskit-ibmq-provider 0.20.2
# Uninstalling qiskit-ibmq-provider-0.20.2:
#   Successfully uninstalled qiskit-ibmq-provider-0.20.2
# WARNING: Skipping qiskit-ignis as it is not installed.
# ...
#   Using cached qiskit-1.3.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# ...
#   Using cached qiskit_aer-0.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.2 kB)
# ...
#   Using cached qiskit_ibmq_provider-0.20.2-py3-none-any.whl.metadata (14 kB)
# ...

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-bdd949994946> in <cell line: 0>()
# ----> 1 from qiskit import IBMQ
#       2
#       3 # Save your IBM Quantum token
#       4 IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
#
# /usr/local/lib/python3.11/dist-packages/qiskit/__init__.py in <module>
#      34     _suppress_error = os.environ.get("QISKIT_SUPPRESS_1_0_IMPORT_ERROR", False) == "1"
#      35     if not _suppress_error and _has_tools:
# ---> 36         raise ImportError(
#      37             "Qiskit is installed in an invalid environment that has both Qiskit >=1.0"
#      38             " and an earlier version."
#
# ...

# %%
# !pip uninstall -y qiskit qiskit-terra qiskit-aer qiskit-ibmq-provider qiskit-ignis # Remove all qiskit related packages
# !pip install qiskit qiskit-aer qiskit-ibmq-provider # Reinstall qiskit, aer and ibmq provider

from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# Found existing installation: qiskit 1.3.1
# Uninstalling qiskit-1.3.1:
#   Successfully uninstalled qiskit-1.3.1
# Found existing installation: qiskit-terra 0.46.3
# Uninstalling qiskit-terra-0.46.3:
#   Successfully uninstalled qiskit-terra-0.46.3
# Found existing installation: qiskit-aer 0.16.0
# Uninstalling qiskit-aer-0.16.0:
#   Successfully uninstalled qiskit-aer-0.16.0
# Found existing installation: qiskit-ibmq-provider 0.20.2
# Uninstalling qiskit-ibmq-provider-0.20.2:
#   Successfully uninstalled qiskit-ibmq-provider-0.20.2
# WARNING: Skipping qiskit-ignis as it is not installed.
# ...
#   Using cached qiskit-1.3.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# ...
#   Using cached qiskit_aer-0.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.2 kB)
# ...
#   Using cached qiskit_ibmq_provider-0.20.2-py3-none-any.whl.metadata (14 kB)
# ...

# %%
from qiskit import Aer, QuantumCircuit
print("Qiskit is installed and Aer is available!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-76360a961a47> in <cell line: 1>()
# ----> 1 from qiskit import Aer, QuantumCircuit
#       2 print("Qiskit is installed and Aer is available!")
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/usr/local/lib/python3.10/dist-packages/qiskit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
provider = IBMQ.get_provider(hub='ibm-q')
print("Available Backends:")
print([backend.name() for backend in provider.backends()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-884a04e64743> in <cell line: 0>()
# ----> 1 provider = IBMQ.get_provider(hub='ibm-q')
#       2 print("Available Backends:")
#       3 print([backend.name() for backend in provider.backends()])
#
# NameError: name 'IBMQ' is not defined

# %%
# !pip install qiskit-ibmq-provider # Ensure the provider package is installed
from qiskit import IBMQ

# Load your IBM Quantum account. You might need to save your account first using IBMQ.save_account() if not done already.
IBMQ.load_account()

provider = IBMQ.get_provider(hub='ibm-q')
print("Available Backends:")
print([backend.name() for backend in provider.backends()])
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-36ecf4978552> in <cell line: 0>()
#       1 get_ipython().system('pip install qiskit-ibmq-provider # Ensure the provider package is installed')
# ----> 2 from qiskit import IBMQ
#       3
#       4 # Load your IBM Quantum account. You might need to save your account first using IBMQ.save_account() if not done already.
#       5 IBMQ.load_account()
#
# /usr/local/lib/python3.11/dist-packages/qiskit/__init__.py in <module>
#      34     _suppress_error = os.environ.get("QISKIT_SUPPRESS_1_0_IMPORT_ERROR", False) == "1"
#      35     if not _suppress_error and _has_tools:
# ---> 36         raise ImportError(
#      37             "Qiskit is installed in an invalid environment that has both Qiskit >=1.0"
#      38             " and an earlier version."
#
# ...

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-bdd949994946> in <cell line: 0>()
# ----> 1 from qiskit import IBMQ
#       2
#       3 # Save your IBM Quantum token
#       4 IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
#
# /usr/local/lib/python3.11/dist-packages/qiskit/__init__.py in <module>
#      34     _suppress_error = os.environ.get("QISKIT_SUPPRESS_1_0_IMPORT_ERROR", False) == "1"
#      35     if not _suppress_error and _has_tools:
# ---> 36         raise ImportError(
#      37             "Qiskit is installed in an invalid environment that has both Qiskit >=1.0"
#      38             " and an earlier version."
#
# ...

# %%
# !pip uninstall -y qiskit qiskit-terra qiskit-aer qiskit-ibmq-provider qiskit-ignis  # Uninstall all Qiskit related packages to ensure a clean environment
# !pip install qiskit qiskit-aer qiskit-ibmq-provider # Reinstall the necessary packages for Qiskit 1.x

# Now, import the necessary modules:
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# Found existing installation: qiskit 1.3.1
# Uninstalling qiskit-1.3.1:
#   Successfully uninstalled qiskit-1.3.1
# Found existing installation: qiskit-terra 0.46.3
# Uninstalling qiskit-terra-0.46.3:
#   Successfully uninstalled qiskit-terra-0.46.3
# Found existing installation: qiskit-aer 0.16.0
# Uninstalling qiskit-aer-0.16.0:
#   Successfully uninstalled qiskit-aer-0.16.0
# Found existing installation: qiskit-ibmq-provider 0.20.2
# Uninstalling qiskit-ibmq-provider-0.20.2:
#   Successfully uninstalled qiskit-ibmq-provider-0.20.2
# WARNING: Skipping qiskit-ignis as it is not installed.
# ...
#   Using cached qiskit-1.3.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# ...
#   Using cached qiskit_aer-0.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.2 kB)
# ...
#   Using cached qiskit_ibmq_provider-0.20.2-py3-none-any.whl.metadata (14 kB)
# ...

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-bdd949994946> in <cell line: 0>()
# ----> 1 from qiskit import IBMQ
#       2
#       3 # Save your IBM Quantum token
#       4 IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
#
# /usr/local/lib/python3.11/dist-packages/qiskit/__init__.py in <module>
#      34     _suppress_error = os.environ.get("QISKIT_SUPPRESS_1_0_IMPORT_ERROR", False) == "1"
#      35     if not _suppress_error and _has_tools:
# ---> 36         raise ImportError(
#      37             "Qiskit is installed in an invalid environment that has both Qiskit >=1.0"
#      38             " and an earlier version."
#
# ...

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)!pip uninstall -y qiskit qiskit-terra qiskit-aer qiskit-ibmq-provider qiskit-ignis  # Uninstall all Qiskit related packages to ensure a clean environment
# !pip install qiskit-ibmq-provider  # Reinstall the necessary packages for Qiskit

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)

# %%
# !pip uninstall -y qiskit qiskit-terra qiskit-aer qiskit-ibmq-provider qiskit-ignis  # Uninstall all Qiskit related packages to ensure a clean environment
# !pip install qiskit-ibmq-provider  # Reinstall the necessary packages for Qiskit
# Out:
# Found existing installation: qiskit 1.3.1
# Uninstalling qiskit-1.3.1:
#   Successfully uninstalled qiskit-1.3.1
# Found existing installation: qiskit-terra 0.46.3
# Uninstalling qiskit-terra-0.46.3:
#   Successfully uninstalled qiskit-terra-0.46.3
# Found existing installation: qiskit-aer 0.16.0
# Uninstalling qiskit-aer-0.16.0:
#   Successfully uninstalled qiskit-aer-0.16.0
# Found existing installation: qiskit-ibmq-provider 0.20.2
# Uninstalling qiskit-ibmq-provider-0.20.2:
#   Successfully uninstalled qiskit-ibmq-provider-0.20.2
# WARNING: Skipping qiskit-ignis as it is not installed.
# ...
#   Using cached qiskit_ibmq_provider-0.20.2-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached qiskit_terra-0.46.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# ...
# Using cached qiskit_ibmq_provider-0.20.2-py3-none-any.whl (241 kB)
# Using cached qiskit_terra-0.46.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# ...

# %%
# !pip install qiskit-ibmq-provider

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)!pip uninstall -y qiskit qiskit-terra qiskit-aer qiskit-ibmq-provider qiskit-ignis  # Uninstall all Qiskit related packages to ensure a clean environment
# !pip install qiskit

# %%
# !pip install qiskit-!pip uninstall -y qiskit
# !pip install qiskit qiskit-aer
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -y
# ...

# %%
# !pip show qiskit
# !pip show qiskit-aer
# Out:
# Name: qiskit
# Version: 1.3.1
# Summary: An open-source SDK for working with quantum computers at the level of extended quantum circuits, operators, and primitives.
# Home-page: https://www.ibm.com/quantum/qiskit
# Author:
# Author-email: Qiskit Development Team <qiskit@us.ibm.com>
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: dill, numpy, python-dateutil, rustworkx, scipy, stevedore, symengine, sympy, typing-extensions
# Required-by: qiskit-aer
# Name: qiskit-aer
# Version: 0.15.1
# Summary: Aer - High performance simulators for Qiskit
# Home-page: https://github.com/Qiskit/qiskit-aer
# Author: AER Development Team
# Author-email: qiskit@us.ibm.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, psutil, qiskit, scipy
# Required-by:

# %%
from qiskit import Aer, QuantumCircuit
print("Qiskit and Aer are successfully installed!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-665e961dd3f1> in <cell line: 1>()
# ----> 1 from qiskit import Aer, QuantumCircuit
#       2 print("Qiskit and Aer are successfully installed!")
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/usr/local/lib/python3.10/dist-packages/qiskit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram

# Create a quantum circuit with 1 qubit and 1 classical bit
qc = QuantumCircuit(1, 1)

# Apply a Hadamard gate to create superposition
qc.h(0)

# Measure the qubit
qc.measure(0, 0)

# Run the circuit on the Aer simulator
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc, backend=simulator, shots=1024).result()

# Get and visualize the results
counts = result.get_counts()
print("Counts:", counts)
plot_histogram(counts)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-5e75b351f47a> in <cell line: 1>()
# ----> 1 from qiskit import QuantumCircuit, Aer, execute
#       2 from qiskit.visualization import plot_histogram
#       3
#       4 # Create a quantum circuit with 1 qubit and 1 classical bit
#       5 qc = QuantumCircuit(1, 1)
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/usr/local/lib/python3.10/dist-packages/qiskit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# <ipython-input-17-bdd949994946>:1: FutureWarning: The `qiskit` package is not installed, only `qiskit-terra` is installed. Starting in Qiskit 1.0.0 only the `qiskit` package will be published. Migrate any requirements files still using `qiskit-terra` to use `qiskit` instead. See https://qisk.it/1-0-packaging-migration for more detail.
#   from qiskit import IBMQ
# <ipython-input-17-bdd949994946>:4: DeprecationWarning: The qiskit.IBMQ entrypoint and the qiskit-ibmq-provider package (accessible from 'qiskit.providers.ibmq`) are deprecated and will be removed in a future release. Instead you should use the qiskit-ibm-provider package which is accessible from 'qiskit_ibm_provider'. You can install it with 'pip install qiskit_ibm_provider'. Just replace 'qiskit.IBMQ' with 'qiskit_ibm_provider.IBMProvider'
#   IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# ...

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.providers.ibmq import least_busy

# Create a 3-qubit quantum circuit
qc = QuantumCircuit(3)
qc.h([0, 1, 2])  # Apply Hadamard gates to put qubits in superposition
qc.measure_all()  # Measure all qubits

# Choose the least busy backend
backend = least_busy(provider.backends(filters=lambda x: x.configuration().n_qubits >= 3 and not x.configuration().simulator and x.status().operational==True))
print(f"Running on backend: {backend.name()}")

# Execute the circuit
job = execute(qc, backend, shots=1024)
result = job.result()
counts = result.get_counts()
print("Counts:", counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-4ff12c598ab2> in <cell line: 0>()
#       8
#       9 # Choose the least busy backend
# ---> 10 backend = least_busy(provider.backends(filters=lambda x: x.configuration().n_qubits >= 3 and not x.configuration().simulator and x.status().operational==True))
#      11 print(f"Running on backend: {backend.name()}")
#      12
#
# NameError: name 'provider' is not defined

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.providers.ibmq import least_busy
from qiskit import IBMQ

# Load your IBM Quantum account
IBMQ.load_account()

# Get the provider
provider = IBMQ.get_provider(hub='ibm-q')  # Replace 'ibm-q' with your hub if different


# Create a 3-qubit quantum circuit
qc = QuantumCircuit(3)
qc.h([0, 1, 2])  # Apply Hadamard gates to put qubits in superposition
qc.measure_all()  # Measure all qubits

# Choose the least busy backend
backend = least_busy(provider.backends(filters=lambda x: x.configuration().n_qubits >= 3 and not x.configuration().simulator and x.status().operational==True))
print(f"Running on backend: {backend.name()}")

# Execute the circuit
job = execute(qc, backend, shots=1024)
result = job.result()
counts = result.get_counts()
print("Counts:", counts)
# Out:
# ibmqfactory.load_account:WARNING:2025-01-16 09:01:03,946: Credentials are already in use. The existing account in the session will be replaced.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/qiskit/providers/ibmq/api/session.py in request(self, method, url, bare, **kwargs)
#     277             response = super().request(method, final_url, headers=headers, **kwargs)
# --> 278             response.raise_for_status()
#     279         except RequestException as ex:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.quantum.ibm.com/api/Network/ibm-q/Groups/open/Projects/main/devices/ibm_kyiv/queue/status
#
# ...

# %%
# !pip install qiskit-ibm-runtime # Install the runtime package

from qiskit_ibm_runtime import QiskitRuntimeService, Session, Sampler

# Save your IBM Quantum token (if not already done)
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)

# Load your IBM Quantum account
IBMQ.load_account()

# Initialize the runtime service
service = QiskitRuntimeService()

# Get the backend you want (e.g., 'ibm_kyiv')
backend = service.backend('ibm_kyiv')

# Create a 3-qubit quantum circuit
qc = QuantumCircuit(3)
qc.h([0, 1, 2])  # Apply Hadamard gates to put qubits in superposition
qc.measure_all()  # Measure all qubits

# Use a session to run the circuit
with Session(service=service, backend=backend):
    sampler = Sampler()
    job = sampler.run(qc, shots=1024)
    result = job.result()
    counts = result.get_counts()
    print("Counts:", counts)

# %%
# !pip install qiskit-ibm-runtime # Install the runtime package

from qiskit_ibm_runtime import QiskitRuntimeService, Session, Sampler

# Save your IBM Quantum token (if not already done)
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)

# Load your IBM Quantum account
IBMQ.load_account()

# Initialize the runtime service
service = QiskitRuntimeService()

# Get the backend you want (e.g., 'ibm_kyiv')
backend = service.backend('ibm_kyiv')

# Create a 3-qubit quantum circuit
qc = QuantumCircuit(3)
qc.h([0, 1, 2])  # Apply Hadamard gates to put qubits in superposition
qc.measure_all()  # Measure all qubits

# Use a session to run the circuit
with Session(service=service, backend=backend):
    sampler = Sampler()
    job = sampler.run(qc, shots=1024)
    result = job.result()
    counts = result.get_counts()
    print("Counts:", counts)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 9.7 MB/s eta 0:00:00
# ...
#   Using cached qiskit-1.3.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 48.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.8/340.8 kB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 32.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 69.4 MB/s eta 0:00:00
# Using cached qiskit-1.3.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.27.2
#     Uninstalling pydantic_core-2.27.2:
#       Successfully uninstalled pydantic_core-2.27.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.5
#     Uninstalling pydantic-2.10.5:
# ...

# %%
# !pip install qiskit-ibm-runtime # Install the runtime package

from qiskit_ibm_runtime import QiskitRuntimeService, Session, Sampler

# Save your IBM Quantum token (if not already done)
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)

# Load your IBM Quantum account
IBMQ.load_account()

# Initialize the runtime service
service = QiskitRuntimeService()

# Get the backend you want (e.g., 'ibm_kyiv')
backend = service.backend('ibm_kyiv')

# Create a 3-qubit quantum circuit
qc = QuantumCircuit(3)
qc.h([0, 1, 2])  # Apply Hadamard gates to put qubits in superposition
qc.measure_all()  # Measure all qubits

# Use a session to run the circuit
with Session(service=service, backend=backend):
    sampler = Sampler()
    job = sampler.run(qc, shots=1024)
    result = job.result()
    counts = result.get_counts()
    print("Counts:", counts)

# %%
# !pip install qiskit-ibm-runtime # Install the runtime package

from qiskit_ibm_runtime import QiskitRuntimeService, Session, Sampler

# Save your IBM Quantum token (if not already done)
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)

# Load your IBM Quantum account
IBMQ.load_account()

# Initialize the runtime service
service = QiskitRuntimeService()

# Get the backend you want (e.g., 'ibm_kyiv')
backend = service.backend('ibm_kyiv')

# Create a 3-qubit quantum circuit
qc = QuantumCircuit(3)
qc.h([0, 1, 2])  # Apply Hadamard gates to put qubits in superposition
qc.measure_all()  # Measure all qubits

# Use a session to run the circuit
with Session(service=service, backend=backend):
    sampler = Sampler()
    job = sampler.run(qc, shots=1024)
    result = job.result()
    counts = result.get_counts()
    print("Counts:", counts)
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-5f55485f7206> in <cell line: 0>()
#       1 get_ipython().system('pip install qiskit-ibm-runtime # Install the runtime package')
#       2
# ----> 3 from qiskit_ibm_runtime import QiskitRuntimeService, Session, Sampler
#       4
#       5 # Save your IBM Quantum token (if not already done)
#
# /usr/local/lib/python3.11/dist-packages/qiskit_ibm_runtime/__init__.py in <module>
#     203 import warnings
#     204
# --> 205 from .qiskit_runtime_service import QiskitRuntimeService
#     206 from .ibm_backend import IBMBackend
#     207 from .runtime_job import RuntimeJob
#
# /usr/local/lib/python3.11/dist-packages/qiskit_ibm_runtime/qiskit_runtime_service.py in <module>
#      21 from typing import Dict, Callable, Optional, Union, List, Any, Type, Sequence
#      22
# ...

# %%
# !pip install qiskit-ibm-runtime  # Install the Qiskit Runtime package

from qiskit import QuantumCircuit
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler, Session

# Save your IBM Quantum token
from qiskit import IBMQ
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)

# Load your IBM Quantum account
IBMQ.load_account()

# Initialize the Qiskit Runtime service
service = QiskitRuntimeService()

# Create a 3-qubit quantum circuit
qc = QuantumCircuit(3, 3)  # 3 qubits, 3 classical bits for measurement
qc.h([0, 1, 2])  # Apply Had
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-01a54f5c722e> in <cell line: 0>()
#       1 get_ipython().system('pip install qiskit-ibm-runtime  # Install the Qiskit Runtime package')
#       2
# ----> 3 from qiskit import QuantumCircuit
#       4 from qiskit_ibm_runtime import QiskitRuntimeService, Sampler, Session
#       5
#
# /usr/local/lib/python3.11/dist-packages/qiskit/__init__.py in <module>
#      34     _suppress_error = os.environ.get("QISKIT_SUPPRESS_1_0_IMPORT_ERROR", False) == "1"
#      35     if not _suppress_error and _has_tools:
# ---> 36         raise ImportError(
#      37             "Qiskit is installed in an invalid environment that has both Qiskit >=1.0"
#      38             " and an earlier version."
#
# ...

# %%
# !pip uninstall -y qiskit qiskit-terra qiskit-aer qiskit-ibmq-provider qiskit-ignis  # Uninstall all Qiskit related packages to ensure a clean environment
# !pip install qiskit-ibmq-provider  # Reinstall the necessary packages for Qiskit

# %%
IBMQ.load_account()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-beb09c0bf764> in <cell line: 0>()
# ----> 1 IBMQ.load_account()
#
# NameError: name 'IBMQ' is not defined

# %%
from qiskit import IBMQ  # Import the IBMQ class

IBMQ.load_account()  # Load the account
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-4a8162153445> in <cell line: 0>()
# ----> 1 from qiskit import IBMQ  # Import the IBMQ class
#       2
#       3 IBMQ.load_account()  # Load the account
#
# /usr/local/lib/python3.11/dist-packages/qiskit/__init__.py in <module>
#      34     _suppress_error = os.environ.get("QISKIT_SUPPRESS_1_0_IMPORT_ERROR", False) == "1"
#      35     if not _suppress_error and _has_tools:
# ---> 36         raise ImportError(
#      37             "Qiskit is installed in an invalid environment that has both Qiskit >=1.0"
#      38             " and an earlier version."
#
# ...

# %%
# !pip uninstall -y qiskit qiskit-terra qiskit-aer qiskit-ibmq-provider qiskit-ignis  # Uninstall all Qiskit related packages to ensure a clean environment
# !pip install qiskit-ibmq-provider  # Reinstall the necessary packages for Qiskit

# Now, import the necessary modules:
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee30
# Out:
#   File "<ipython-input-5-8a2c2b3ed615>", line 8
#     IBMQ.save_account('6d5a8e5c3ef56d12047ee30
#                       ^
# SyntaxError: unterminated string literal (detected at line 8)

# %%
# !pip install qiskit qiskit-aer

# %%
from qiskit import Aer, QuantumCircuit
print("Qiskit and Aer are successfully installed!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-665e961dd3f1> in <cell line: 1>()
# ----> 1 from qiskit import Aer, QuantumCircuit
#       2 print("Qiskit and Aer are successfully installed!")
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/usr/local/lib/python3.10/dist-packages/qiskit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram

# Create a quantum circuit with 1 qubit and 1 classical bit
qc = QuantumCircuit(1, 1)

# Apply a Hadamard gate to create superposition
qc.h(0)

# Measure the qubit
qc.measure(0, 0)

# Run the circuit on the Aer simulator
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc, backend=simulator, shots=1024).result()

# Get and visualize the results
counts = result.get_counts()
print("Counts:", counts)
plot_histogram(counts)f
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-5e75b351f47a> in <cell line: 1>()
# ----> 1 from qiskit import QuantumCircuit, Aer, execute
#       2 from qiskit.visualization import plot_histogram
#       3
#       4 # Create a quantum circuit with 1 qubit and 1 classical bit
#       5 qc = QuantumCircuit(1, 1)
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/usr/local/lib/python3.10/dist-packages/qiskit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from qiskit import Aer, QuantumCircuit
print("Qiskit and Aer are successfully installed!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-665e961dd3f1> in <cell line: 1>()
# ----> 1 from qiskit import Aer, QuantumCircuit
#       2 print("Qiskit and Aer are successfully installed!")
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/usr/local/lib/python3.10/dist-packages/qiskit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from qiskit import QuantumCircuit
from qiskit.providers.aer import Aer

print("Qiskit and Aer are successfully installed!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-ef5c07906d90> in <cell line: 2>()
#       1 from qiskit import QuantumCircuit
# ----> 2 from qiskit.providers.aer import Aer
#       3
#       4 print("Qiskit and Aer are successfully installed!")
#
# ModuleNotFoundError: No module named 'qiskit.providers.aer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install qiskit qiskit-aer

# %%
from qiskit import QuantumCircuit
from qiskit.providers.aer import Aer

print("Qiskit and Aer are successfully installed!")

# %%
from qiskit import QuantumCircuit
from qiskit.providers.aer import Aer

print("Qiskit and Aer are successfully installed!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-ef5c07906d90> in <cell line: 2>()
#       1 from qiskit import QuantumCircuit
# ----> 2 from qiskit.providers.aer import Aer
#       3
#       4 print("Qiskit and Aer are successfully installed!")
#
# ModuleNotFoundError: No module named 'qiskit.providers.aer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip show qiskit
# !pip show qiskit-aer
# Out:
# Name: qiskit
# Version: 1.3.1
# Summary: An open-source SDK for working with quantum computers at the level of extended quantum circuits, operators, and primitives.
# Home-page: https://www.ibm.com/quantum/qiskit
# Author:
# Author-email: Qiskit Development Team <qiskit@us.ibm.com>
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: dill, numpy, python-dateutil, rustworkx, scipy, stevedore, symengine, sympy, typing-extensions
# Required-by: qiskit-aer
# Name: qiskit-aer
# Version: 0.15.1
# Summary: Aer - High performance simulators for Qiskit
# Home-page: https://github.com/Qiskit/qiskit-aer
# Author: AER Development Team
# Author-email: qiskit@us.ibm.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, psutil, qiskit, scipy
# Required-by:

# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram

# Create a quantum circuit with 1 qubit and 1 classical bit
qc = QuantumCircuit(1, 1)

# Apply a Hadamard gate to create superposition
qc.h(0)

# Measure the qubit
qc.measure(0, 0)

# Run the circuit on the Aer simulator
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc, backend=simulator, shots=1024).result()

# Get and visualize the results
counts = result.get_counts()
print("Counts:", counts)
plot_histogram(counts)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-5e75b351f47a> in <cell line: 1>()
# ----> 1 from qiskit import QuantumCircuit, Aer, execute
#       2 from qiskit.visualization import plot_histogram
#       3
#       4 # Create a quantum circuit with 1 qubit and 1 classical bit
#       5 qc = QuantumCircuit(1, 1)
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/usr/local/lib/python3.10/dist-packages/qiskit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip uninstall -y qiskit

# %%
# !pip uninstall -y qiskit qiskit-terra qiskit-aer qiskit-ibmq-provider qiskit-ignis  # Uninstall all Qiskit related packages to ensure a clean environment
# !pip install qiskit-ibmq-provider  # Reinstall the necessary packages for Qiskit
# Out:
# Found existing installation: qiskit 1.3.1
# Uninstalling qiskit-1.3.1:
#   Successfully uninstalled qiskit-1.3.1
# Found existing installation: qiskit-terra 0.46.3
# Uninstalling qiskit-terra-0.46.3:
#   Successfully uninstalled qiskit-terra-0.46.3
# WARNING: Skipping qiskit-aer as it is not installed.
# Found existing installation: qiskit-ibmq-provider 0.20.2
# Uninstalling qiskit-ibmq-provider-0.20.2:
#   Successfully uninstalled qiskit-ibmq-provider-0.20.2
# WARNING: Skipping qiskit-ignis as it is not installed.
# ...
#   Using cached qiskit_ibmq_provider-0.20.2-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached qiskit_terra-0.46.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# ...
# Using cached qiskit_ibmq_provider-0.20.2-py3-none-any.whl (241 kB)
# Using cached qiskit_terra-0.46.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# ...

# %%
from qiskit import IBMQ

# Save your IBM Quantum token
IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# Out:
# <ipython-input-1-bdd949994946>:1: FutureWarning: The `qiskit` package is not installed, only `qiskit-terra` is installed. Starting in Qiskit 1.0.0 only the `qiskit` package will be published. Migrate any requirements files still using `qiskit-terra` to use `qiskit` instead. See https://qisk.it/1-0-packaging-migration for more detail.
#   from qiskit import IBMQ
# <ipython-input-1-bdd949994946>:4: DeprecationWarning: The qiskit.IBMQ entrypoint and the qiskit-ibmq-provider package (accessible from 'qiskit.providers.ibmq`) are deprecated and will be removed in a future release. Instead you should use the qiskit-ibm-provider package which is accessible from 'qiskit_ibm_provider'. You can install it with 'pip install qiskit_ibm_provider'. Just replace 'qiskit.IBMQ' with 'qiskit_ibm_provider.IBMProvider'
#   IBMQ.save_account('6d5a8e5c3ef56d12047ee307c066e758e4d40df37f63f14c93922d043587cac9d6ab9c5d97ee729ee1a285f942d8ab028821b310ce0b960064f0d9140a40e4b2', overwrite=True)
# ...

# %%
provider = IBMQ.get_provider(hub='ibm-q')
print("Available Backends:")
print([backend.name() for backend in provider.backends()])
# Out:
# ---------------------------------------------------------------------------
# IBMQProviderError                         Traceback (most recent call last)
# <ipython-input-2-884a04e64743> in <cell line: 0>()
# ----> 1 provider = IBMQ.get_provider(hub='ibm-q')
#       2 print("Available Backends:")
#       3 print([backend.name() for backend in provider.backends()])
#
# /usr/local/lib/python3.11/dist-packages/qiskit/providers/ibmq/ibmqfactory.py in get_provider(self, hub, group, project)
#     421
#     422         if not providers:
# --> 423             raise IBMQProviderError('No provider matches the specified criteria: '
#     424                                     'hub = {}, group = {}, project = {}'
#     425                                     .format(hub, group, project))
#
# IBMQProviderError: 'No provider matches the specified criteria: hub = ibm-q, group = None, project = None'
